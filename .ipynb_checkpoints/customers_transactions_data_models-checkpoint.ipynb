# %%
# !pip install duckdb # uncomment run if not installed
# Out:
# Requirement already satisfied: duckdb in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (1.2.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install dbt-core # uncomment run if not installed
# Out:
# Requirement already satisfied: dbt-core in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (1.9.4)
# Requirement already satisfied: agate<1.10,>=1.7.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (1.9.1)
# Requirement already satisfied: Jinja2<4,>=3.1.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (3.1.4)
# Requirement already satisfied: mashumaro[msgpack]<3.15,>=3.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (3.14)
# Requirement already satisfied: click<9.0,>=8.0.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (8.1.8)
# Requirement already satisfied: networkx<4.0,>=2.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (3.4.2)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (5.29.4)
# Requirement already satisfied: requests<3.0.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (2.32.3)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (1.1.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (0.12.1)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (0.5.1)
# Requirement already satisfied: dbt-semantic-interfaces<0.8,>=0.7.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (0.7.4)
# Requirement already satisfied: dbt-common<2.0,>=1.13.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (1.17.0)
# Requirement already satisfied: dbt-adapters<2.0,>=1.10.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (1.14.4)
# Requirement already satisfied: packaging>20.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (24.1)
# Requirement already satisfied: pytz>=2015.7 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (2024.1)
# Requirement already satisfied: pyyaml>=6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (1.3.46)
# Requirement already satisfied: typing-extensions>=4.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core) (4.13.0)
# Requirement already satisfied: Babel>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (2.16.0)
# Requirement already satisfied: isodate>=0.5.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (0.6.1)
# Requirement already satisfied: leather>=0.3.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<1.10,>=1.7.0->dbt-core) (1.1.8)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2.0,>=1.13.0->dbt-core) (0.4.6)
# Requirement already satisfied: deepdiff<8.0,>=7.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2.0,>=1.13.0->dbt-core) (7.0.1)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2.0,>=1.13.0->dbt-core) (4.23.0)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2.0,>=1.13.0->dbt-core) (2.9.0.post0)
# Requirement already satisfied: importlib-metadata<7,>=6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (6.11.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (10.6.0)
# Requirement already satisfied: pydantic<3,>=1.10 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (2.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from Jinja2<4,>=3.1.3->dbt-core) (2.1.5)
# Requirement already satisfied: msgpack>=0.5.6 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-core) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-core) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-core) (2024.8.30)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from deepdiff<8.0,>=7.0->dbt-common<2.0,>=1.13.0->dbt-core) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from importlib-metadata<7,>=6.0->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (3.21.0)
# Requirement already satisfied: six in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from isodate>=0.5.4->agate<1.10,>=1.7.0->dbt-core) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.13.0->dbt-core) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.13.0->dbt-core) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.13.0->dbt-core) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.13.0->dbt-core) (0.20.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core) (0.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from python-slugify>=1.2.1->agate<1.10,>=1.7.0->dbt-core) (1.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install dbt-duckdb # uncomment run if not installed
# Out:
# Requirement already satisfied: dbt-duckdb in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (1.9.2)
# Requirement already satisfied: dbt-common<2,>=1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-duckdb) (1.17.0)
# Requirement already satisfied: dbt-adapters<2,>=1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-duckdb) (1.14.4)
# Requirement already satisfied: duckdb>=1.0.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-duckdb) (1.2.1)
# Requirement already satisfied: dbt-core>=1.8.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-duckdb) (1.9.4)
# Requirement already satisfied: agate<2.0,>=1.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (1.9.1)
# Requirement already satisfied: mashumaro[msgpack]<3.15,>=3.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (3.14)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (5.29.4)
# Requirement already satisfied: pytz>=2015.7 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (2024.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (4.13.0)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.4.6)
# Requirement already satisfied: deepdiff<8.0,>=7.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (7.0.1)
# Requirement already satisfied: isodate<0.7,>=0.6 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.6.1)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (3.1.4)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (4.23.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.12.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-common<2,>=1->dbt-duckdb) (2.32.3)
# Requirement already satisfied: click<9.0,>=8.0.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (8.1.8)
# Requirement already satisfied: networkx<4.0,>=2.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (3.4.2)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.1.0)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.5.1)
# Requirement already satisfied: dbt-semantic-interfaces<0.8,>=0.7.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.7.4)
# Requirement already satisfied: packaging>20.9 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (24.1)
# Requirement already satisfied: pyyaml>=6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.3.46)
# Requirement already satisfied: Babel>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.16.0)
# Requirement already satisfied: leather>=0.3.2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.1.8)
# Requirement already satisfied: importlib-metadata<7,>=6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (6.11.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (10.6.0)
# Requirement already satisfied: pydantic<3,>=1.10 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (2.11.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from deepdiff<8.0,>=7.0->dbt-common<2,>=1->dbt-duckdb) (4.1.0)
# Requirement already satisfied: six in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from isodate<0.7,>=0.6->dbt-common<2,>=1->dbt-duckdb) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jinja2<4,>=3.1.3->dbt-common<2,>=1->dbt-duckdb) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.20.0)
# Requirement already satisfied: msgpack>=0.5.6 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2,>=1->dbt-duckdb) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (2024.8.30)
# Requirement already satisfied: zipp>=0.5 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from importlib-metadata<7,>=6.0->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (0.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install pyyaml # uncomment run if not installed
# Out:
# Requirement already satisfied: pyyaml in /Users/coop/Desktop/dev_projects/virtualenv/lib/python3.12/site-packages (6.0.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import duckdb
import os
import yaml

# %%
# set path for local duckdb db
db_name = 'my_db.duckdb'
db_directory = os.path.join(os.getcwd(), db_name)

# %%
# change db path in profiles.yml
profiles_path = os.path.join(os.getcwd(),'customers_transactions_dbt','profiles.yml')
with open(profiles_path,'r') as file:
    dbt_profiles = yaml.safe_load(file)
    
dbt_profiles['main_db']['outputs']['dev']['path'] = db_directory

with open(profiles_path, 'w') as file:
    yaml.dump(dbt_profiles, file, default_flow_style = False)

# %%
connection = duckdb.connect(db_directory)

# %%
# load customers data set into db
connection.execute("""
    drop table if exists customers;
    create table if not exists customers 
    (
        customer_id int
        ,created_at timestamp
    );
    copy customers from 'customers.csv' (header true)
""")

# %%
# load subscription_state_changes data set into db
connection.execute("""
    drop table if exists subscription_state_changes;
    create table if not exists subscription_state_changes 
    (
        subscription_change_id varchar
        ,subscription_id varchar
        ,customer_id int
        ,subscription_change_timestamp timestamp -- changed column name for readability
        ,start_state varchar
        ,end_state varchar
    );
    copy subscription_state_changes from 'subscription_changes.csv' (header true)
""")

# %%
# load transactions data set into db
connection.execute("""
    drop table if exists transactions;
    create table if not exists transactions 
    (
        transaction_id varchar
        ,subscription_id varchar
        ,customer_id int
        ,transaction_timestamp timestamp
        ,net_revenue decimal
        ,category varchar
        ,category_type_id int -- added column to add detail
    );
    copy transactions from 'transactions.csv' (header true)
""")

# %%
# check for existing locks on db (connections)
# !lsof my_db.duckdb
# Out:
# COMMAND     PID USER   FD   TYPE DEVICE SIZE/OFF    NODE NAME
# python3.1 28817 coop   65u   REG   1,17  2109440 7095045 my_db.duckdb

# %%
connection.close()

# %%
# confirm locks are removed
# !lsof my_db.duckdb
# Out:
# COMMAND     PID USER   FD   TYPE DEVICE SIZE/OFF    NODE NAME
# python3.1 28817 coop   65u   REG   1,17  2109440 7095045 my_db.duckdb

# %%
# run dbt workflow
# !cd customers_transactions && dbt run
# Out:
# zsh:cd:1: no such file or directory: customers_transactions

# %%
connection = duckdb.connect(db_directory)

# %%
connection.execute("""
    select * from dim_customer_acquisition
""").fetchdf()
# Out:
#     customer_id customer_created_timestamp acquisition_timestamp  \
# 0          7406        2024-06-21 04:14:25   2024-06-21 04:14:25
# 1          7841        2025-03-07 22:34:26   2025-03-07 22:34:26
# 2          8233        2025-02-01 19:54:44   2025-02-01 19:54:44
# 3          8233        2025-02-01 19:54:44   2025-02-01 19:54:44
# 4          1896        2024-03-22 01:40:10   2024-03-22 01:40:10
# 5          1896        2024-03-22 01:40:10   2024-03-22 01:40:10
# 6          7079        2024-08-20 05:55:14   2024-08-20 05:55:14
# 7          1926        2024-07-30 01:44:57   2024-07-30 01:44:57
# 8          9453        2024-12-03 14:42:11   2024-12-09 14:42:11
# 9          1715        2024-05-01 10:33:11   2024-05-01 10:33:11
# 10         3756        2024-05-14 04:45:17   2024-06-06 04:45:17
# 11         3418        2024-04-14 07:13:08   2024-05-07 07:13:08
#
#    acquisition_type subscription_id subscription_start_timestamp  \
# 0              gift       sub_35054          2024-06-26 04:14:25
# 1      subscription       sub_74635          2025-03-07 22:34:26
# 2           alacart       sub_63639          2025-02-07 19:54:44
# 3           alacart       sub_88361          2025-03-04 19:38:49
# 4      subscription       sub_74860          2024-03-22 01:40:10
# 5      subscription       sub_16352          2024-10-27 14:51:02
# 6              gift       sub_16622          2024-09-10 05:55:14
# 7              gift       sub_20975          2024-08-25 01:44:57
# 8      subscription            None                          NaT
# 9              gift            None                          NaT
# 10     subscription            None                          NaT
# 11     subscription            None                          NaT
#
#    subscription_end_timestamp prior_subscription_id
# 0         2024-11-22 00:16:39                  None
# 1         2025-03-10 20:35:32                  None
# 2         2025-03-04 19:38:48                  None
# 3                         NaT             sub_63639
# 4         2024-10-27 14:51:01                  None
# 5                         NaT             sub_74860
# 6         2024-11-29 02:09:50                  None
# 7         2024-11-22 02:52:19                  None
# 8                         NaT                  None
# 9                         NaT                  None
# 10                        NaT                  None
# 11                        NaT                  None

# %%
connection.execute("""
    select * from cube_customer_transaction_behavior
""").fetchdf()
# Out:
#     transaction_year  transaction_month acquisition_type  acquisition_year  \
# 0               2025                  3     subscription              2025
# 1               2025                  3          alacart              2025
# 2               2025                  2          alacart              2025
# 3               2025                  2          alacart              2025
# 4               2025                  2     subscription              2024
# 5               2025                  1     subscription              2024
# 6               2024                 12     subscription              2024
# 7               2024                 11             gift              2024
# 8               2024                 11             gift              2024
# 9               2024                 11             gift              2024
# 10              2024                 10     subscription              2024
# 11              2024                  9             gift              2024
# 12              2024                  8             gift              2024
# 13              2024                  8             gift              2024
# 14              2024                  8             gift              2024
# 15              2024                  7     subscription              2024
# 16              2024                  7             gift              2024
# 17              2024                  6             gift              2024
# 18              2024                  6     subscription              2024
# 19              2024                  6             gift              2024
# 20              2024                  5             gift              2024
# 21              2024                  5     subscription              2024
# 22              2024                  3     subscription              2024
#
#     acquisition_month customer_type      category  total_customers  \
# 0                   3           new  subscription                1
# 1                   2      existing  subscription                1
# 2                   2           new       alacart                1
# 3                   2           new  subscription                1
# 4                  12      existing          gift                1
# 5                   6      existing       alacart                1
# 6                  12           new  subscription                1
# 7                   7      existing  subscription                1
# 8                   8      existing  subscription                1
# 9                   6      existing  subscription                1
# 10                  3      existing  subscription                1
# 11                  8      existing  subscription                1
# 12                  7      existing  subscription                1
# 13                  5      existing  subscription                1
# 14                  8           new          gift                1
# 15                  5      existing       alacart                1
# 16                  7           new          gift                1
# 17                  6           new          gift                1
# 18                  6           new  subscription                1
# 19                  6           new  subscription                1
# 20                  5           new          gift                1
# 21                  5           new  subscription                1
# 22                  3           new  subscription                1
#
#     total_transactions  total_net_revenue
# 0                    2              63.00
# 1                    2              71.40
# 2                    1              23.89
# 3                    1              31.50
# 4                    1              17.32
# 5                    1              10.35
# 6                    1              39.90
# 7                    1              39.90
# 8                    1              39.90
# 9                    1              39.90
# 10                   1              31.50
# 11                   1              31.50
# 12                   1              39.90
# 13                   1              31.50
# 14                   1              34.56
# 15                   1             120.88
# 16                   1              82.34
# 17                   1              62.29
# 18                   1              39.90
# 19                   1              31.50
# 20                   1              43.21
# 21                   1              39.90
# 22                   1              39.90

# %%
connection.close()
